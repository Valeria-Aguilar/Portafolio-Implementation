# %%
import numpy as np
from gradiente_manual import gradiente_manual
from gradiente_librerias import gradiente_librerias

# Dataset sintético
np.random.seed(42)                     # Semilla para reproducibilidad
X = 2 * np.random.rand(100, 1)         # 100 valores de X entre 0 y 2
y = 4 + 3 * X + np.random.randn(100, 1) # Recta con un poco de ruido


#Hiperparámetros
alpha = 0.1          # tasa de aprendizaje (α)
n_iterations = 1000 # número de iteraciones

gradiente_manual(X, y, alpha, n_iterations)
gradiente_librerias(X, y, alpha, n_iterations)
# Out:
# Parámetros finales (θ0, θ1): [4.21509616 2.77011339]
# Parámetros finales (θ0, θ1): [6.88272137] [1.62281182]
